# %% [markdown]
# # Dataset - `50_Startups.csv`

# %% [markdown]
# # 1. Import Libraries: Import the necessary libraries.

# %%
import pandas as pd

# %% [markdown]
# # 2. Import Dataset: Import the dataset `50_Startups.csv`

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # 3. Exploratory Data Analysis:
# ## Check the `State` column to understand its unique values.

# %%
df['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %% [markdown]
# # 4. Feature Selection: Split the dataset into input (independent variables)
# ## and output (dependent variable/Profit).

# %%
X = df[['R&D Spend','Administration','Marketing Spend']]

# %%
y = df['Profit']

# %% [markdown]
# # 5. Data Preprocessing (Encoding):
# ## Convert the 'State' column into a numeric column using transformation.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['State'] = le.fit_transform(df['State'])

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State     Profit
# 0  165349.20       136897.80        471784.10      2  192261.83
# 1  162597.70       151377.59        443898.53      0  191792.06
# 2  153441.51       101145.55        407934.54      1  191050.39
# 3  144372.41       118671.85        383199.62      2  182901.99
# 4  142107.34        91391.77        366168.42      1  166187.94

# %% [markdown]
# # 6. Dummy Variable Trap:
# ## Handle the dummy variable trap (if manual encoding was used).

# %% [markdown]
# **Not require to do**

# %% [markdown]
# # 7. Train-Test Split: Split the dataset into Training and Testing sets.

# %%
X = df.drop('Profit',axis =1 )
y=df['Profit']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# # 8. Model Initialization:
# ## Import the `LinearRegression` model from the `linear_model` family.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 9. Model Training:
# ## Fit the `Linear Regression` model to the training data.

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 10. Prediction & Evaluation:
# ## (Implied next steps) Predict results and compare them with actual values.

# %%
y_pred =  model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_pred) *100
r2
# Out:
# 90.00614254946403
